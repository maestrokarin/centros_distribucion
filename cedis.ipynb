# %% [markdown]
# ### Código para obtener los centros de distribución de Soriana, Chedraui y Walmart

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import googlemaps
import folium
import os
import zipfile
from tqdm import tqdm
import geopandas as gpd
from selenium import webdriver
import time
from branca.element import Template, MacroElement
import re

# %% [markdown]
# #### Función general

# %%
def get_html(url, encoding=None, verify=False):
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers, verify=verify)
    if encoding is not None:
        response.encoding = encoding
    return BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# ##### Soriana

# %%
soriana=get_html(url["Soriana"], "utf-8")
# Out:
# C:\Users\claud\miniconda3\lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.organizacionsoriana.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
#Obtener todo lo de la tabla
tabla=soriana.find_all("table", {"class": "table table-striped"})

# %%
all_tables_data = []  # Lista vacía

for table in tabla:  # Iterar sobre cada tabla
    headers = [th.get_text().strip() for th in table.find_all('th')]  # Obtener headers
    table_data = []  # Lista vacía para almacenar los datos de la tabla
    rows = table.find_all('tr')  # Obtener todas las filas de la tabla
    
    for row in rows:  # iterar sobre cada fila
        cells = row.find_all('td')  # Obtener las celdas de la fila
        if cells:  # Si hay celdas en la fila
            row_data = [cell.get_text().strip() for cell in cells]  
            if row_data:  # Si hay datos en la fila
                table_data.append(dict(zip(headers, row_data)))  # Agregar los datos de la fila a la lista de datos de la tabla

    if table_data:  # Si hay datos en la tabla
        all_tables_data.append(table_data)  # Agregar los datos de la tabla a la lista de datos de todas las tablas

# %%
#Pasar la lista a un dataframe
soriana_df=pd.DataFrame()
for i in range(len(all_tables_data)):
    soriana_df=pd.concat([soriana_df, pd.DataFrame(all_tables_data[i])], ignore_index=True)
# Reordenar la df
df_reorganized = pd.DataFrame(columns=["nombre", "direccion", "tipo"])

rename_map = {
    "CENTROS DE DISTRIBUCIÓN FRESCOS": "Fresco",
    "CENTROS DE DISTRIBUCIÓN SECOS": "Seco",
    "CENTRO DE DISTRIBUCIÓN  E-COMMERCE": "E-Commerce"
}


for _, row in soriana_df.iterrows():
    
    for col_name, tipo in rename_map.items():
        if pd.notna(row[col_name]):
            df_reorganized =pd.concat([df_reorganized, pd.DataFrame([[row[col_name], row["DIRECCIÓN"], tipo]], columns=["nombre", "direccion", "tipo"])], ignore_index=True)
soriana_df=df_reorganized
#Añadir tienda
soriana_df["tienda"]="Soriana"
soriana_df
# Out:
#                   nombre                                          direccion  \
# 0   CDF Salinas Victoria  Carretera Salinas-Victoria km.5.5 Col. Satélit...
# 1         CDF Cuautitlán  Autopista México-Querétaro km 36.8,C.P. 54700 ...
# 2       CDF Villahermosa  Carretera Villahermosa-Cárdenas Km 164.1,Ranch...
# 3        CDF Guadalajara  Periférico Sur Manuel Gómez Morín No. 5890,Col...
# 4            CDF Tijuana  Prolongación Club de Leones 10535.Fraccionamie...
# 5         CDF Hermosillo  Av. Chetumal entre Guatemala y Belice No. 1121...
# 6   CDS Salinas Victoria  Carretera Salinas-Victoria km.5.5 Col. Satélit...
# 7          CDS Tultitlán  Km. 14.5 Carretera Puente de Vigas Cuautitlán,...
# 8          CDS Querétaro  Autopista México-Querétaro Km 186 S/N, Col Ent...
# 9        CDS Guadalajara  Periférico Sur Manuel Gómez Morín #5890, Col. ...
# 10      CDS Villahermosa  Carretera Villahermosa-Cárdenas Km 164.1,Ranch...
# 11           CDS Tijuana  Av. Juan Alesio y Acapulco S/N y Blvd.Parque I...
# 12           CDEC México  Blvd. Benito Juárez 10 Bodega i3, San Mateo Cu...
#
#           tipo   tienda
# 0       Fresco  Soriana
# 1       Fresco  Soriana
# 2       Fresco  Soriana
# 3       Fresco  Soriana
# 4       Fresco  Soriana
# 5       Fresco  Soriana
# 6         Seco  Soriana
# 7         Seco  Soriana
# 8         Seco  Soriana
# 9         Seco  Soriana
# 10        Seco  Soriana
# 11        Seco  Soriana
# 12  E-Commerce  Soriana

# %% [markdown]
# ##### Chedraui

# %%
chedraui=get_html(url["Chedraui"],encoding="utf-8",verify=False)
# Out:
# C:\Users\claud\miniconda3\lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.grupochedraui.com.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
#Obtener resultados
results=chedraui.find_all("div", {"class": "col-lg-12"})

#Obtener los nombres de los centros de distribución
nombres=chedraui.find_all("h2", {"class": "font-bold font-color-naranja font-size-18"})
direcciones=chedraui.find_all("ul", {"class": "ventajas-ul"})
#Obtener las direcciones
direcciones=[direccion.get_text().strip() for direccion in direcciones]
#Eliminar los saltos de línea y los espacios
direcciones=[direccion.replace("\n", "").replace("  ", "").replace("\t", " ") for direccion in direcciones]

#Pasar a un dataframe
chedraui_df=pd.DataFrame({"nombre": [nombre.get_text().strip() for nombre in nombres],
                          "direccion": direcciones})

chedraui_df["tienda"]="Chedraui"
chedraui_df
# Out:
#                                 nombre  \
# 0        Centro de Distribución Cancún
# 1   Centro de Distribución Guadalajara
# 2        Centro de Distribución La Paz
# 3     Centro de Distribución Monterrey
# 4    Centro de Distribución Teoloyucan
# 5      Centro de Distribución Veracruz
# 6  Centro de Distribución Villahermosa
# 7       Centro de Distribución Tampico
#
#                                            direccion    tienda
# 0  Carr. Cancún - Puerto Morelos, Km. 329.5 Cancú...  Chedraui
# 1  Carretera El Verde, El Castillo No. 2000, Col....  Chedraui
# 2  Colima S/N, Col. Pueblo Nuevo, La Paz Baja Cal...  Chedraui
# 3  Jaime Nuno No. 3660, Col. Del Norte, Monterrey...  Chedraui
# 4  Carretera Cuautitlán-Zumpango Lt. 28 Mz. 825, ...  Chedraui
# 5  Carretera Veracruz-Cardel, Calle tres zapotes ...  Chedraui
# 6  Carretera Villahermosa-Macuspana Km. 12.5, Cor...  Chedraui
# 7  Av. Hidalgo No. 501, Col. Del Pueblo, Tampico,...  Chedraui

# %%
driver = webdriver.Chrome()
driver.get(url["Walmart"])
time.sleep(5)
html=driver.page_source
driver.quit()

# %%
walmart=BeautifulSoup(html, "html.parser")

# %%
results=walmart.find_all("a", {"class": "hfpxzc"})
results
# Out:
# [<a aria-label="Cedis eCommerce Walmart" class="hfpxzc" href="https://www.google.com.mx/maps/place/Cedis+eCommerce+Walmart/data=!4m7!3m6!1s0x85d2214c2617819f:0x2ac0d663c0d44ef6!8m2!3d19.7467676!4d-99.204067!16s%2Fg%2F11gtynlbtp!19sChIJn4EXJkwh0oUR9k7UwGPWwCo?authuser=0&amp;hl=es-419&amp;rclk=1" jsaction="pane.wfvdle5;focus:pane.wfvdle5;blur:pane.wfvdle5;auxclick:pane.wfvdle5;keydown:pane.wfvdle5;clickmod:pane.wfvdle5" jslog="12690;track:click,contextmenu;mutable:true;metadata:WyIwYWhVS0V3aVJyWTJpOFBtR0F4Vk82Y2tESGRJUEE2WVE4QmN
coordinates=[]


for url in links:  
    matches = re.findall(r'!3d([-\d.]+)!4d([-\d.]+)', url)
    if matches:
        latitude, longitude = matches[0]  
        coordinates.append((latitude, longitude))

# %%
#Pegar nombres y coordenadas en un dataframe
walmart_df=pd.DataFrame({"nombre": nombres, "coordenadas": coordinates})
walmart_df["tienda"]="Walmart"
#Split coordenadas
walmart_df["lat"]=walmart_df["coordenadas"].apply(lambda x: x[0])
walmart_df["lon"]=walmart_df["coordenadas"].apply(lambda x: x[1])
#Eliminar coordenadas
walmart_df.drop("coordenadas", axis=1, inplace=True)
#Minusculas en nombres
walmart_df["nombre"]=walmart_df["nombre"].str.lower()
#Eliminar duplicados en nombres
walmart_df.drop_duplicates(subset="nombre", inplace=True)
walmart_df
# Out:
#                            nombre   tienda         lat           lon
# 0         cedis ecommerce walmart  Walmart  19.7467676    -99.204067
# 1         cedis walmart ecommerce  Walmart  20.4796628  -103.2616698
# 2       walmart cedis perecederos  Walmart  20.5675263  -103.3682508
# 3       cedis walmart perecederos  Walmart  17.9862983    -93.193946
# 4           walmart ecommerce mty  Walmart  25.7950038   -100.282875
# 5   walmart cedis perecederos vsa  Walmart  17.9836486   -93.1960445
# 6  centro de distribucion walmart  Walmart  17.9814468   -93.1635841
# 7  cedis villahermosa perecederos  Walmart  17.9863452   -93.1955754
# 8            cedis walmart la luz  Walmart   19.695354    -99.200388
# 9      cedis walmart refrigerados  Walmart  25.8846732  -100.2346366

# %% [markdown]
# #### Geocodear

# %%
#Pegar los dos dataframes
df=pd.concat([soriana_df, chedraui_df], ignore_index=True)
df
# Out:
#                                  nombre  \
# 0                  CDF Salinas Victoria
# 1                        CDF Cuautitlán
# 2                      CDF Villahermosa
# 3                       CDF Guadalajara
# 4                           CDF Tijuana
# 5                        CDF Hermosillo
# 6                  CDS Salinas Victoria
# 7                         CDS Tultitlán
# 8                         CDS Querétaro
# 9                       CDS Guadalajara
# 10                     CDS Villahermosa
# 11                          CDS Tijuana
# 12                          CDEC México
# 13        Centro de Distribución Cancún
# 14   Centro de Distribución Guadalajara
# 15        Centro de Distribución La Paz
# 16     Centro de Distribución Monterrey
# 17    Centro de Distribución Teoloyucan
# 18      Centro de Distribución Veracruz
# 19  Centro de Distribución Villahermosa
# 20       Centro de Distribución Tampico
#
#                                             direccion        tipo    tienda
# 0   Carretera Salinas-Victoria km.5.5 Col. Satélit...      Fresco   Soriana
# 1   Autopista México-Querétaro km 36.8,C.P. 54700 ...      Fresco   Soriana
# 2   Carretera Villahermosa-Cárdenas Km 164.1,Ranch...      Fresco   Soriana
# 3   Periférico Sur Manuel Gómez Morín No. 5890,Col...      Fresco   Soriana
# 4   Prolongación Club de Leones 10535.Fraccionamie...      Fresco   Soriana
# 5   Av. Chetumal entre Guatemala y Belice No. 1121...      Fresco   Soriana
# 6   Carretera Salinas-Victoria km.5.5 Col. Satélit...        Seco   Soriana
# 7   Km. 14.5 Carretera Puente de Vigas Cuautitlán,...        Seco   Soriana
# 8   Autopista México-Querétaro Km 186 S/N, Col Ent...        Seco   Soriana
# 9   Periférico Sur Manuel Gómez Morín #5890, Col. ...        Seco   Soriana
# 10  Carretera Villahermosa-Cárdenas Km 164.1,Ranch...        Seco   Soriana
# 11  Av. Juan Alesio y Acapulco S/N y Blvd.Parque I...        Seco   Soriana
# 12  Blvd. Benito Juárez 10 Bodega i3, San Mateo Cu...  E-Commerce   Soriana
# 13  Carr. Cancún - Puerto Morelos, Km. 329.5 Cancú...         NaN  Chedraui
# 14  Carretera El Verde, El Castillo No. 2000, Col....         NaN  Chedraui
# 15  Colima S/N, Col. Pueblo Nuevo, La Paz Baja Cal...         NaN  Chedraui
# 16  Jaime Nuno No. 3660, Col. Del Norte, Monterrey...         NaN  Chedraui
# 17  Carretera Cuautitlán-Zumpango Lt. 28 Mz. 825, ...         NaN  Chedraui
# 18  Carretera Veracruz-Cardel, Calle tres zapotes ...         NaN  Chedraui
# 19  Carretera Villahermosa-Macuspana Km. 12.5, Cor...         NaN  Chedraui
# 20  Av. Hidalgo No. 501, Col. Del Pueblo, Tampico,...         NaN  Chedraui

# %%
#Credenciales de Google Maps API desde txt. Se debe crear un archivo de texto con las credenciales. Esto es personal.
with open("C:/Users/maestrokarin/Documents/credencialesgmaps.txt", "r") as file:
    api_key=file.read().strip()

gmaps=googlemaps.Client(key=api_key)

# %%
#Geocodificar las direcciones y ponerlo en la columna de coordenadas
df["coordenadas"]=df["direccion"].apply(lambda x: gmaps.geocode(x)[0]["geometry"]["location"])
#Crear dos columnas con las coordenadas
df["lat"]=df["coordenadas"].apply(lambda x: x["lat"])
df["lon"]=df["coordenadas"].apply(lambda x: x["lng"])
#Dropear la columna de coordenadas
df=df.drop(columns=["coordenadas"])
df
# Out:
#                                  nombre  \
# 0                  CDF Salinas Victoria
# 1                        CDF Cuautitlán
# 2                      CDF Villahermosa
# 3                       CDF Guadalajara
# 4                           CDF Tijuana
# 5                        CDF Hermosillo
# 6                  CDS Salinas Victoria
# 7                         CDS Tultitlán
# 8                         CDS Querétaro
# 9                       CDS Guadalajara
# 10                     CDS Villahermosa
# 11                          CDS Tijuana
# 12                          CDEC México
# 13        Centro de Distribución Cancún
# 14   Centro de Distribución Guadalajara
# 15        Centro de Distribución La Paz
# 16     Centro de Distribución Monterrey
# 17    Centro de Distribución Teoloyucan
# 18      Centro de Distribución Veracruz
# 19  Centro de Distribución Villahermosa
# 20       Centro de Distribución Tampico
#
#                                             direccion        tipo    tienda  \
# 0   Carretera Salinas-Victoria km.5.5 Col. Satélit...      Fresco   Soriana
# 1   Autopista México-Querétaro km 36.8,C.P. 54700 ...      Fresco   Soriana
# 2   Carretera Villahermosa-Cárdenas Km 164.1,Ranch...      Fresco   Soriana
# 3   Periférico Sur Manuel Gómez Morín No. 5890,Col...      Fresco   Soriana
# 4   Prolongación Club de Leones 10535.Fraccionamie...      Fresco   Soriana
# 5   Av. Chetumal entre Guatemala y Belice No. 1121...      Fresco   Soriana
# 6   Carretera Salinas-Victoria km.5.5 Col. Satélit...        Seco   Soriana
# 7   Km. 14.5 Carretera Puente de Vigas Cuautitlán,...        Seco   Soriana
# 8   Autopista México-Querétaro Km 186 S/N, Col Ent...        Seco   Soriana
# 9   Periférico Sur Manuel Gómez Morín #5890, Col. ...        Seco   Soriana
# 10  Carretera Villahermosa-Cárdenas Km 164.1,Ranch...        Seco   Soriana
# 11  Av. Juan Alesio y Acapulco S/N y Blvd.Parque I...        Seco   Soriana
# 12  Blvd. Benito Juárez 10 Bodega i3, San Mateo Cu...  E-Commerce   Soriana
# 13  Carr. Cancún - Puerto Morelos, Km. 329.5 Cancú...         NaN  Chedraui
# 14  Carretera El Verde, El Castillo No. 2000, Col....         NaN  Chedraui
# 15  Colima S/N, Col. Pueblo Nuevo, La Paz Baja Cal...         NaN  Chedraui
# 16  Jaime Nuno No. 3660, Col. Del Norte, Monterrey...         NaN  Chedraui
# 17  Carretera Cuautitlán-Zumpango Lt. 28 Mz. 825, ...         NaN  Chedraui
# 18  Carretera Veracruz-Cardel, Calle tres zapotes ...         NaN  Chedraui
# 19  Carretera Villahermosa-Macuspana Km. 12.5, Cor...         NaN  Chedraui
# 20  Av. Hidalgo No. 501, Col. Del Pueblo, Tampico,...         NaN  Chedraui
#
#           lat         lon
# 0   25.897103 -100.262871
# 1   19.720678  -99.208614
# 2   17.974040  -93.130237
# 3   20.578165 -103.349850
# 4   32.442181 -117.004557
# 5   29.107349 -111.002822
# 6   25.897103 -100.262871
# 7   19.512170  -99.214350
# 8   20.529097 -100.175101
# 9   20.578165 -103.349850
# 10  17.974040  -93.130237
# 11  32.459390 -116.989100
# 12  19.627052  -99.151503
# 13  20.842046  -86.907313
# 14  20.566528 -103.283121
# 15  24.142157 -110.323434
# 16  25.585116 -100.266769
# 17  19.757849  -99.158069
# 18  19.225595  -96.233044
# 19  17.982282  -92.825473
# 20  22.224410  -97.863676

# %%
#Sustituir lat y long del registro 6 por 29.115216575023382, -111.00023263067902
df.loc[5, "lat"]=29.115216575023382
df.loc[5, "lon"]=-111.00023263067902

# %%
#Pegar waalmart y df
df=pd.concat([df, walmart_df], ignore_index=True)
df
# Out:
#                                  nombre  \
# 0                  CDF Salinas Victoria
# 1                        CDF Cuautitlán
# 2                      CDF Villahermosa
# 3                       CDF Guadalajara
# 4                           CDF Tijuana
# 5                        CDF Hermosillo
# 6                  CDS Salinas Victoria
# 7                         CDS Tultitlán
# 8                         CDS Querétaro
# 9                       CDS Guadalajara
# 10                     CDS Villahermosa
# 11                          CDS Tijuana
# 12                          CDEC México
# 13        Centro de Distribución Cancún
# 14   Centro de Distribución Guadalajara
# 15        Centro de Distribución La Paz
# 16     Centro de Distribución Monterrey
# 17    Centro de Distribución Teoloyucan
# 18      Centro de Distribución Veracruz
# 19  Centro de Distribución Villahermosa
# 20       Centro de Distribución Tampico
# 21              cedis ecommerce walmart
# 22              cedis walmart ecommerce
# 23            walmart cedis perecederos
# 24            cedis walmart perecederos
# 25                walmart ecommerce mty
# 26        walmart cedis perecederos vsa
# 27       centro de distribucion walmart
# 28       cedis villahermosa perecederos
# 29                 cedis walmart la luz
# 30           cedis walmart refrigerados
#
#                                             direccion        tipo    tienda  \
# 0   Carretera Salinas-Victoria km.5.5 Col. Satélit...      Fresco   Soriana
# 1   Autopista México-Querétaro km 36.8,C.P. 54700 ...      Fresco   Soriana
# 2   Carretera Villahermosa-Cárdenas Km 164.1,Ranch...      Fresco   Soriana
# 3   Periférico Sur Manuel Gómez Morín No. 5890,Col...      Fresco   Soriana
# 4   Prolongación Club de Leones 10535.Fraccionamie...      Fresco   Soriana
# 5   Av. Chetumal entre Guatemala y Belice No. 1121...      Fresco   Soriana
# 6   Carretera Salinas-Victoria km.5.5 Col. Satélit...        Seco   Soriana
# 7   Km. 14.5 Carretera Puente de Vigas Cuautitlán,...        Seco   Soriana
# 8   Autopista México-Querétaro Km 186 S/N, Col Ent...        Seco   Soriana
# 9   Periférico Sur Manuel Gómez Morín #5890, Col. ...        Seco   Soriana
# 10  Carretera Villahermosa-Cárdenas Km 164.1,Ranch...        Seco   Soriana
# 11  Av. Juan Alesio y Acapulco S/N y Blvd.Parque I...        Seco   Soriana
# 12  Blvd. Benito Juárez 10 Bodega i3, San Mateo Cu...  E-Commerce   Soriana
# 13  Carr. Cancún - Puerto Morelos, Km. 329.5 Cancú...         NaN  Chedraui
# 14  Carretera El Verde, El Castillo No. 2000, Col....         NaN  Chedraui
# 15  Colima S/N, Col. Pueblo Nuevo, La Paz Baja Cal...         NaN  Chedraui
# 16  Jaime Nuno No. 3660, Col. Del Norte, Monterrey...         NaN  Chedraui
# 17  Carretera Cuautitlán-Zumpango Lt. 28 Mz. 825, ...         NaN  Chedraui
# 18  Carretera Veracruz-Cardel, Calle tres zapotes ...         NaN  Chedraui
# 19  Carretera Villahermosa-Macuspana Km. 12.5, Cor...         NaN  Chedraui
# 20  Av. Hidalgo No. 501, Col. Del Pueblo, Tampico,...         NaN  Chedraui
# 21                                                NaN         NaN   Walmart
# 22                                                NaN         NaN   Walmart
# 23                                                NaN         NaN   Walmart
# 24                                                NaN         NaN   Walmart
# 25                                                NaN         NaN   Walmart
# 26                                                NaN         NaN   Walmart
# 27                                                NaN         NaN   Walmart
# 28                                                NaN         NaN   Walmart
# 29                                                NaN         NaN   Walmart
# 30                                                NaN         NaN   Walmart
#
#            lat           lon
# 0    25.897103   -100.262871
# 1    19.720678    -99.208614
# 2     17.97404    -93.130237
# 3    20.578165    -103.34985
# 4    32.442181   -117.004557
# 5    29.115217   -111.000233
# 6    25.897103   -100.262871
# 7     19.51217     -99.21435
# 8    20.529097   -100.175101
# 9    20.578165    -103.34985
# 10    17.97404    -93.130237
# 11    32.45939     -116.9891
# 12   19.627052    -99.151503
# 13   20.842046    -86.907313
# 14   20.566528   -103.283121
# 15   24.142157   -110.323434
# 16   25.585116   -100.266769
# 17   19.757849    -99.158069
# 18   19.225595    -96.233044
# 19   17.982282    -92.825473
# 20    22.22441    -97.863676
# 21  19.7467676    -99.204067
# 22  20.4796628  -103.2616698
# 23  20.5675263  -103.3682508
# 24  17.9862983    -93.193946
# 25  25.7950038   -100.282875
# 26  17.9836486   -93.1960445
# 27  17.9814468   -93.1635841
# 28  17.9863452   -93.1955754
# 29   19.695354    -99.200388
# 30  25.8846732  -100.2346366

# %%
mapa = folium.Map(location=[19.432608, -99.133209], zoom_start=6, tiles="http://www.google.cn/maps/vt?lyrs=s@189&gl=cn&x={x}&y={y}&z={z}", attr="Google Satellite")


def get_marker_color(tienda_value):
    colors = {
        'Soriana': 'green',
        'Chedraui': 'orange',
        'Walmart': 'blue'
    }
    return colors.get(tienda_value, 'gray')  


for _, row in df.iterrows():
    # Tooltip
    tooltip_text = f"<b>Nombre:</b> {row['nombre']}<br><b>Dirección:</b> {row['direccion']}<br><b>Tipo:</b> {row['tipo']}<br><b>Tienda:</b> {row['tienda']}"
    # marker
    folium.Marker(
        [row["lat"], row["lon"]],
        tooltip=tooltip_text,
        size=15,
        icon=folium.Icon(color=get_marker_color(row['tienda']))
    ).add_to(mapa)




template = """
{% macro html(this, kwargs) %}
<div style="position: fixed; 
     top: 50px; left: 50px; width: 150px; height: auto; 
     border:2px solid grey; z-index:9998; font-size:14px;
     background-color:white; opacity: 0.8; padding: 5px; margin-bottom: 20px;">
    &nbsp; <b>Tiendas</b> <br>
    &nbsp; Walmart &nbsp; <i class="fa fa-circle" style="color:lightblue;"></i><br>
    &nbsp; Soriana &nbsp; <i class="fa fa-circle" style="color:green;"></i><br>
    &nbsp; Chedraui &nbsp; <i class="fa fa-circle" style="color:orange;"></i><br>
</div>
<div style="position: fixed; 
     bottom: 50px; left: 50px; width: 900px; 
     z-index:9997; font-size:12px; 
     color: black;
     background-color:white; opacity: 0.8; padding: 5px; margin-top: 20px;">
    <strong>Fuentes:</strong> <br>
    <a href="https://www.organizacionsoriana.com/centros_de_distribucion.html" target="_blank">Soriana: www.organizacionsoriana.com/centros_de_distribucion.html</a><br>
    <a href="https://www.grupochedraui.com.mx/en/division_logistica/index.html" target="_blank">Chedraui: www.grupochedraui.com.mx/en/division_logistica/index.html</a><br>
    <a href="https://www.google.com.mx/maps/search/cedis+perecederos+walmart+ecommerce/@21.7065157,-103.5592671,6z/data=!3m1!4b1?entry=ttu" target="_blank">Walmart: https://www.google.com.mx/maps/search/cedis+perecederos+walmart+ecommerce/@21.7065157,-103.5592671,6z/data=!3m1!4b1?entry=ttu</a><br>
</div>
{% endmacro %}
"""


macro = MacroElement()
macro._template = Template(template)
macro.urls = url


mapa.get_root().add_child(macro)
folium.LayerControl().add_to(mapa)
# mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49b1a79e231245fd507cb59ff527db0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49b1a79e231245fd507cb59ff527db0b&quot; &gt;&lt;/div&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      top: 50px; left: 50px; width: 150px; height: auto;
#      border:2px solid grey; z-index:9998; font-size:14px;
#      background-color:white; opacity: 0.8; padding: 5px; margin-bottom: 20px;&quot;&gt;
#     &amp;nbsp; &lt;b&gt;Tiendas&lt;/b&gt; &lt;br&gt;
#     &amp;nbsp; Walmart &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:lightblue;&quot;&gt;&lt;/i&gt;&lt;br&gt;
#     &amp;nbsp; Soriana &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green;&quot;&gt;&lt;/i&gt;&lt;br&gt;
#     &amp;nbsp; Chedraui &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:orange;&quot;&gt;&lt;/i&gt;&lt;br&gt;
# &lt;/div&gt;
# &lt;div style=&quot;position: fixed;
#      bottom: 50px; left: 50px; width: 900px;
#      z-index:9997; font-size:12px;
#      color: black;
#      background-color:white; opacity: 0.8; padding: 5px; margin-top: 20px;&quot;&gt;
#     &lt;strong&gt;Fuentes:&lt;/strong&gt; &lt;br&gt;
#     &lt;a href=&quot;https://www.organizacionsoriana.com/centros_de_distribucion.html&quot; target=&quot;_blank&quot;&gt;Soriana: www.organizacionsoriana.com/centros_de_distribucion.html&lt;/a&gt;&lt;br&gt;
#     &lt;a href=&quot;https://www.grupochedraui.com.mx/en/division_logistica/index.html&quot; target=&quot;_blank&quot;&gt;Chedraui: www.grupochedraui.com.mx/en/division_logistica/index.html&lt;/a&gt;&lt;br&gt;
#     &lt;a href=&quot;https://www.google.com.mx/maps/search/cedis+perecederos+walmart+ecommerce/@21.7065157,-103.5592671,6z/data=!3m1!4b1?entry=ttu&quot; target=&quot;_blank&quot;&gt;Walmart: https://www.google.com.mx/maps/search/cedis+perecederos+walmart+ecommerce/@21.7065157,-103.5592671,6z/data=!3m1!4b1?entry=ttu&lt;/a&gt;&lt;br&gt;
# &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49b1a79e231245fd507cb59ff527db0b = L.map(
#                 &quot;map_49b1a79e231245fd507cb59ff527db0b&quot;,
#                 {
#                     center: [19.432608, -99.133209],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc9634f8dd97b37a315b7aa410bca2bd = L.tileLayer(
#                 &quot;http://www.google.cn/maps/vt?lyrs=s@189\u0026gl=cn\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Satellite&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49b1a79e231245fd507cb59ff527db0b);
#
#
#             var marker_006064e2351348c6afcec1f4afef0ea3 = L.marker(
#                 [25.8971034, -100.2628706],
#                 {&quot;size&quot;: 15}
#             ).addTo(map_49b1a79e231245fd507cb59ff527db0b);
#
#
#             var icon_5e5370909e6c098862940d2d9c7bc34f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_006064e2351348c6afcec1f4afef0ea3.setIcon(icon_5e5370909e6c098862940d2d9c7bc34f);
#
#
#             marker_006064e2351348c6afcec1f4afef0ea3.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Nombre:&lt;/b&gt; CDF Salinas Victoria&lt;br&gt;&lt;b&gt;Dirección:&lt;/b&gt; Carretera Salinas-Victoria km.5.5 Col. Satélite,C.P. 65500 Salinas Victoria, Nuevo León.&lt;br&gt;&lt;b&gt;Tipo:&lt;/b&gt; Fresco&lt;br&gt;&lt;b&gt;Tienda:&lt;/b&gt; Soriana
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_69cfe3cfbce615aae3b9c948c7c8ff1b = L.marker(
#                 [19.7206779, -99.2086137],
#                 {&quot;size&quot;: 15}
#             ).addTo(map_49b1a79e231245fd507cb59ff527db0b);
#
#
#             var icon_c931bc53b12bd83a0222b20c17f07204 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_69cfe3cfbce615aae3b9c948c7c8ff1b.setIcon(icon_c931bc53b12bd83a0222b20c17f07204);
#
#
#             marker_69cfe3cfbce615aae3b9c948c7c8ff1b.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Nombre:&lt;/b&gt; CDF Cuautitlán&lt;br&gt;&lt;b&gt;Dirección:&lt;/b&gt; Autopista México-Querétaro km 36.8,C.P. 54700 Cuautitlán Izcalli, Estado de México.&lt;br&gt;&lt;b&gt;Tipo:&lt;/b&gt; Fresco&lt;br&gt;&lt;b&gt;Tienda:&lt;/b&gt; Soriana
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_360a7d80b6c6b64f9304e334450b9296 = L.marker(
#                 [17.9740401, -93.1302367],
#                 {&quot;size&quot;: 15}
#             ).addTo(map_49b1a79e231245fd507cb59ff527db0b);
#
#
#             var icon_60892b1272234106f78b2

# %%
#Salvar mapa
mapa.save("cedis.html")
